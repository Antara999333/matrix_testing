# %% [markdown]
# #### This is the graph for patients most at risk due to shortage of beds during the covid crisis.

# %%
import lib
import numpy as np
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/fivethirtyeight/data/master/covid-geography/mmsa-icu-beds.csv"
df = pd.read_csv(url)

# %%
#I am now going to do the descriptive statistics
print("Data Analysis: ", lib.perform_data_analysis())
# Out:
# count    1.360000e+02
# mean     6.671887e+05
# std      8.847868e+05
# min      1.794153e+04
# 25%      1.587478e+05
# 50%      3.960815e+05
# 75%      9.327925e+05
# max      6.165102e+06
# Name: total_at_risk, dtype: float64
# Data Analysis:  None
